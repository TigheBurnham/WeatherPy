# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-90, 90, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description 
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"] 
        
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kontagora
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | salamiyah
# Processing Record 4 of Set 1 | biltine
# Processing Record 5 of Set 1 | butembo
# Processing Record 6 of Set 1 | zuwarah
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | coquimbo
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | roald
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | rotifunk
# Processing Record 17 of Set 1 | nouakchott
# Processing Record 18 of Set 1 | kuytun
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | acworth
# Processing Record 23 of Set 1 | marv dasht
# City not found. Skipping...
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | teguise
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | matinha
# Processing Record 28 of Set 1 | kangaatsiaq
# Processing Record 29 of Set 1 | bursa
# Processing Record 30 of Set 1 | baijiantan
# Processing Record 31 of Set 1 | khandbari
# Processing Record 32 of Set 1 | ushtobe
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | dingle
# Processing Record 36 of Set 1 | nambutalai
# Processing Record 37 of Set 1 | araouane
# Processing Record 38 of Set 1 | visby
# Processing Record 39 of Set 1 | san cristobal
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | margate
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | abu samrah
# Processing Record 44 of Set 1 | diamantino
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | sao raimundo nonato
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | morlenbach
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | umba
# Processing Record 4 of Set 2 | berlevag
# Processing Record 5 of Set 2 | praia
# Processing Record 6 of Set 2 | siavonga
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | aksu
# Processing Record 9 of Set 2 | alta floresta
# Processing Record 10 of Set 2 | caraquet
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | mana
# Processing Record 14 of Set 2 | grindavik
# Processing Record 15 of Set 2 | chapais
# Processing Record 16 of Set 2 | trofors
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | tukan
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | strezhevoy
# Processing Record 22 of Set 2 | khorixas
# Processing Record 23 of Set 2 | koulikoro
# Processing Record 24 of Set 2 | antalaha
# Processing Record 25 of Set 2 | crotone
# Processing Record 26 of Set 2 | palora
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | lagoa
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | plyussa
# Processing Record 33 of Set 2 | thinadhoo
# Processing Record 34 of Set 2 | turukhansk
# Processing Record 35 of Set 2 | awjilah
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | port antonio
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | bonfim
# Processing Record 41 of Set 2 | sena madureira
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | cocal
# Processing Record 45 of Set 2 | ibra
# Processing Record 46 of Set 2 | arlit
# Processing Record 47 of Set 2 | sandy bay
# Processing Record 48 of Set 2 | axim
# Processing Record 49 of Set 2 | belyy yar
# Processing Record 50 of Set 2 | pemba
# Processing Record 1 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 3 | aksay
# Processing Record 3 of Set 3 | hammerfest
# Processing Record 4 of Set 3 | ergani
# Processing Record 5 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 3 | riachao das neves
# Processing Record 7 of Set 3 | calvinia
# Processing Record 8 of Set 3 | beloha
# Processing Record 9 of Set 3 | praia da vitoria
# Processing Record 10 of Set 3 | catamarca
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | rio gallegos
# Processing Record 13 of Set 3 | san juan
# Processing Record 14 of Set 3 | djambala
# Processing Record 15 of Set 3 | jalpaiguri
# Processing Record 16 of Set 3 | capari
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | buchanan
# Processing Record 19 of Set 3 | duiwelskloof
# Processing Record 20 of Set 3 | la romana
# Processing Record 21 of Set 3 | zatoka
# Processing Record 22 of Set 3 | rocha
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | balboa
# Processing Record 25 of Set 3 | oranjestad
# Processing Record 26 of Set 3 | placido de castro
# Processing Record 27 of Set 3 | mormugao
# Processing Record 28 of Set 3 | mutoko
# Processing Record 29 of Set 3 | lenina
# Processing Record 30 of Set 3 | iralaya
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 3 | tara
# Processing Record 34 of Set 3 | mpanda
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | saryozek
# Processing Record 37 of Set 3 | pimenta bueno
# Processing Record 38 of Set 3 | battle creek
# Processing Record 39 of Set 3 | nynashamn
# Processing Record 40 of Set 3 | coronel martinez
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | vestmannaeyjar
# Processing Record 43 of Set 3 | bereda
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | sao felix do xingu
# Processing Record 46 of Set 3 | thunder bay
# Processing Record 47 of Set 3 | kishtwar
# Processing Record 48 of Set 3 | viedma
# Processing Record 49 of Set 3 | bronnoysund
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | tazovskiy
# Processing Record 2 of Set 4 | narsaq
# Processing Record 3 of Set 4 | yanam
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | hofn
# Processing Record 6 of Set 4 | mocuba
# Processing Record 7 of Set 4 | usinsk
# Processing Record 8 of Set 4 | caucaia
# Processing Record 9 of Set 4 | ndioum
# Processing Record 10 of Set 4 | pimenteiras
# Processing Record 11 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 12 of Set 4 | sisimiut
# Processing Record 13 of Set 4 | lasa
# Processing Record 14 of Set 4 | frutal
# Processing Record 15 of Set 4 | salo
# Processing Record 16 of Set 4 | sirjan
# Processing Record 17 of Set 4 | port-gentil
# Processing Record 18 of Set 4 | bokoro
# Processing Record 19 of Set 4 | hambantota
# Processing Record 20 of Set 4 | fez
# Processing Record 21 of Set 4 | comodoro rivadavia
# Processing Record 22 of Set 4 | pedernales
# Processing Record 23 of Set 4 | malinyi
# Processing Record 24 of Set 4 | burgos
# Processing Record 25 of Set 4 | serov
# Processing Record 26 of Set 4 | bardiyah
# Processing Record 27 of Set 4 | anloga
# Processing Record 28 of Set 4 | pangnirtung
# Processing Record 29 of Set 4 | amargosa
# Processing Record 30 of Set 4 | cardoso
# Processing Record 31 of Set 4 | marienburg
# Processing Record 32 of Set 4 | edgewater
# Processing Record 33 of Set 4 | malakal
# Processing Record 34 of Set 4 | tifton
# Processing Record 35 of Set 4 | gari
# Processing Record 36 of Set 4 | kuryk
# Processing Record 37 of Set 4 | hun
# Processing Record 38 of Set 4 | luis correia
# Processing Record 39 of Set 4 | mabaruma
# Processing Record 40 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 4 | santa cruz
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | graaff-reinet
# Processing Record 44 of Set 4 | camabatela
# Processing Record 45 of Set 4 | matara
# Processing Record 46 of Set 4 | papayal
# Processing Record 47 of Set 4 | harper
# Processing Record 48 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 4 | ambilobe
# Processing Record 50 of Set 4 | gwembe
# Processing Record 1 of Set 5 | ambovombe
# Processing Record 2 of Set 5 | mandera
# Processing Record 3 of Set 5 | savantvadi
# Processing Record 4 of Set 5 | juruti
# Processing Record 5 of Set 5 | opuwo
# Processing Record 6 of Set 5 | kansanshi
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | vetlanda
# Processing Record 9 of Set 5 | tamandare
# Processing Record 10 of Set 5 | sao joao da barra
# Processing Record 11 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | saint anthony
# Processing Record 13 of Set 5 | madingou
# Processing Record 14 of Set 5 | kostomuksha
# Processing Record 15 of Set 5 | biala podlaska
# Processing Record 16 of Set 5 | buraydah
# Processing Record 17 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 18 of Set 5 | gazanjyk
# Processing Record 19 of Set 5 | isiro
# Processing Record 20 of Set 5 | doha
# Processing Record 21 of Set 5 | oil city
# Processing Record 22 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 5 | bakel
# Processing Record 24 of Set 5 | talawdi
# City not found. Skipping...
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | tukrah
# Processing Record 28 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 5 | ouadda
# Processing Record 30 of Set 5 | vityazevo
# Processing Record 31 of Set 5 | muzhi
# Processing Record 32 of Set 5 | touros
# Processing Record 33 of Set 5 | reconquista
# Processing Record 34 of Set 5 | baghdad
# Processing Record 35 of Set 5 | saint-leu
# Processing Record 36 of Set 5 | pokhara
# Processing Record 37 of Set 5 | port shepstone
# Processing Record 38 of Set 5 | ostrovnoy
# Processing Record 39 of Set 5 | abtenau
# Processing Record 40 of Set 5 | gazalkent
# Processing Record 41 of Set 5 | areia branca
# Processing Record 42 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 43 of Set 5 | alenquer
# Processing Record 44 of Set 5 | bubaque
# Processing Record 45 of Set 5 | dudinka
# Processing Record 46 of Set 5 | porto torres
# Processing Record 47 of Set 5 | port hawkesbury
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | chuy
# Processing Record 50 of Set 5 | hit
# Processing Record 1 of Set 6 | lethem
# Processing Record 2 of Set 6 | boueni
# Processing Record 3 of Set 6 | hobe sound
# Processing Record 4 of Set 6 | olinda
# Processing Record 5 of Set 6 | tanout
# Processing Record 6 of Set 6 | husavik
# Processing Record 7 of Set 6 | atkinson
# Processing Record 8 of Set 6 | komsomolskiy
# Processing Record 9 of Set 6 | nauta
# Processing Record 10 of Set 6 | rafai
# Processing Record 11 of Set 6 | ponta delgada
# Processing Record 12 of Set 6 | shchuchye
# City not found. Skipping...
# Processing Record 13 of Set 6 | sidi ali
# Processing Record 14 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 6 | michigan city
# Processing Record 16 of Set 6 | karwar
# Processing Record 17 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 6 | pudozh
# Processing Record 19 of Set 6 | cove
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 6 | muros
# Processing Record 23 of Set 6 | mattru
# Processing Record 24 of Set 6 | clyde river
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | bourges
# Processing Record 30 of Set 6 | neuquen
# Processing Record 31 of Set 6 | gorshechnoye
# Processing Record 32 of Set 6 | bandarbeyla
# Processing Record 33 of Set 6 | khor
# Processing Record 34 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 6 | kommunisticheskiy
# Processing Record 36 of Set 6 | talcahuano
# Processing Record 37 of Set 6 | birjand
# Processing Record 38 of Set 6 | micheweni
# Processing Record 39 of Set 6 | phenix city
# Processing Record 40 of Set 6 | zavetnoye
# Processing Record 41 of Set 6 | walvis bay
# Processing Record 42 of Set 6 | emirdag
# Processing Record 43 of Set 6 | nioro
# Processing Record 44 of Set 6 | kruisfontein
# Processing Record 45 of Set 6 | rawson
# Processing Record 46 of Set 6 | amboasary
# Processing Record 47 of Set 6 | belmonte
# Processing Record 48 of Set 6 | asfi
# Processing Record 49 of Set 6 | marsabit
# Processing Record 50 of Set 6 | carutapera
# Processing Record 1 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 2 of Set 7 | svetlyy
# Processing Record 3 of Set 7 | valdivia
# Processing Record 4 of Set 7 | paragominas
# Processing Record 5 of Set 7 | murmashi
# Processing Record 6 of Set 7 | nouadhibou
# Processing Record 7 of Set 7 | itacoatiara
# Processing Record 8 of Set 7 | goderich
# Processing Record 9 of Set 7 | wajid
# Processing Record 10 of Set 7 | ardu
# Processing Record 11 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 7 | pitkyaranta
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | peterhead
# Processing Record 16 of Set 7 | paita
# Processing Record 17 of Set 7 | porto novo
# Processing Record 18 of Set 7 | maraa
# Processing Record 19 of Set 7 | bandipur
# Processing Record 20 of Set 7 | westport
# Processing Record 21 of Set 7 | lapua
# Processing Record 22 of Set 7 | bonavista
# Processing Record 23 of Set 7 | luena
# Processing Record 24 of Set 7 | atar
# Processing Record 25 of Set 7 | plettenberg bay
# Processing Record 26 of Set 7 | kutum
# Processing Record 27 of Set 7 | bodden town
# Processing Record 28 of Set 7 | marrakesh
# Processing Record 29 of Set 7 | birao
# Processing Record 30 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 7 | codrington
# Processing Record 32 of Set 7 | bouna
# Processing Record 33 of Set 7 | naples
# Processing Record 34 of Set 7 | girne
# Processing Record 35 of Set 7 | bilma
# Processing Record 36 of Set 7 | mogadishu
# Processing Record 37 of Set 7 | najran
# Processing Record 38 of Set 7 | taltal
# Processing Record 39 of Set 7 | carnarvon
# Processing Record 40 of Set 7 | batouri
# Processing Record 41 of Set 7 | dwarka
# Processing Record 42 of Set 7 | port-de-bouc
# Processing Record 43 of Set 7 | rognan
# Processing Record 44 of Set 7 | surt
# Processing Record 45 of Set 7 | yarada
# Processing Record 46 of Set 7 | agadir
# Processing Record 47 of Set 7 | litoral del san juan
# City not found. Skipping...
# Processing Record 48 of Set 7 | aripuana
# Processing Record 49 of Set 7 | rampur
# Processing Record 50 of Set 7 | richards bay
# Processing Record 1 of Set 8 | trussville
# Processing Record 2 of Set 8 | nantucket
# Processing Record 3 of Set 8 | inhambane
# Processing Record 4 of Set 8 | doka
# Processing Record 5 of Set 8 | lucapa
# Processing Record 6 of Set 8 | el tigre
# Processing Record 7 of Set 8 | namibe
# Processing Record 8 of Set 8 | lerik
# Processing Record 9 of Set 8 | santa branca
# Processing Record 10 of Set 8 | suslovo
# Processing Record 11 of Set 8 | garmisch-partenkirchen
# Processing Record 12 of Set 8 | maniitsoq
# Processing Record 13 of Set 8 | raga
# Processing Record 14 of Set 8 | cejkovice
# Processing Record 15 of Set 8 | kristinehamn
# Processing Record 16 of Set 8 | richard toll
# City not found. Skipping...
# Processing Record 17 of Set 8 | altamira
# Processing Record 18 of Set 8 | weligama
# Processing Record 19 of Set 8 | pointe michel
# Processing Record 20 of Set 8 | takoradi
# Processing Record 21 of Set 8 | brae
# Processing Record 22 of Set 8 | igarka
# Processing Record 23 of Set 8 | ancud
# Processing Record 24 of Set 8 | ayagoz
# Processing Record 25 of Set 8 | tutoia
# Processing Record 26 of Set 8 | sassandra
# Processing Record 27 of Set 8 | bud
# Processing Record 28 of Set 8 | havelock
# Processing Record 29 of Set 8 | qasigiannguit
# Processing Record 30 of Set 8 | sao filipe
# Processing Record 31 of Set 8 | los llanos de aridane
# Processing Record 32 of Set 8 | yining
# Processing Record 33 of Set 8 | arapiraca
# Processing Record 34 of Set 8 | yar-sale
# Processing Record 35 of Set 8 | la macarena
# Processing Record 36 of Set 8 | lodeynoye pole
# Processing Record 37 of Set 8 | adrar
# Processing Record 38 of Set 8 | kamenka
# Processing Record 39 of Set 8 | gboko
# Processing Record 40 of Set 8 | umea
# Processing Record 41 of Set 8 | klobuck
# Processing Record 42 of Set 8 | mwene-ditu
# Processing Record 43 of Set 8 | sumbe
# Processing Record 44 of Set 8 | capoterra
# Processing Record 45 of Set 8 | marawi
# Processing Record 46 of Set 8 | gat
# Processing Record 47 of Set 8 | vasteras
# Processing Record 48 of Set 8 | massaguet
# Processing Record 49 of Set 8 | pascagoula
# Processing Record 50 of Set 8 | camapua
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | soyo
# Processing Record 3 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 9 | havre-saint-pierre
# Processing Record 5 of Set 9 | san antonio
# Processing Record 6 of Set 9 | nosy varika
# Processing Record 7 of Set 9 | chamba
# Processing Record 8 of Set 9 | trairi
# Processing Record 9 of Set 9 | sao domingos do maranhao
# Processing Record 10 of Set 9 | valparaiso
# Processing Record 11 of Set 9 | martin
# Processing Record 12 of Set 9 | lages
# Processing Record 13 of Set 9 | manor
# Processing Record 14 of Set 9 | cozumel
# Processing Record 15 of Set 9 | tessalit
# Processing Record 16 of Set 9 | wajir
# Processing Record 17 of Set 9 | vizinga
# Processing Record 18 of Set 9 | huancabamba
# Processing Record 19 of Set 9 | hualmay
# Processing Record 20 of Set 9 | nioki
# Processing Record 21 of Set 9 | antofagasta
# Processing Record 22 of Set 9 | vytegra
# Processing Record 23 of Set 9 | rio grande
# Processing Record 24 of Set 9 | omboue
# Processing Record 25 of Set 9 | jacmel
# Processing Record 26 of Set 9 | cabanas
# Processing Record 27 of Set 9 | izhma
# Processing Record 28 of Set 9 | abha
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | dingli
# Processing Record 31 of Set 9 | saint-joseph
# Processing Record 32 of Set 9 | ravar
# Processing Record 33 of Set 9 | kirovskiy
# Processing Record 34 of Set 9 | diveyevo
# Processing Record 35 of Set 9 | carndonagh
# Processing Record 36 of Set 9 | ngora
# Processing Record 37 of Set 9 | faya
# Processing Record 38 of Set 9 | morlaix
# Processing Record 39 of Set 9 | quimper
# Processing Record 40 of Set 9 | hamilton
# Processing Record 41 of Set 9 | itapirapua
# Processing Record 42 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 9 | staroutkinsk
# Processing Record 44 of Set 9 | calabozo
# Processing Record 45 of Set 9 | muleba
# Processing Record 46 of Set 9 | monte alegre
# Processing Record 47 of Set 9 | skjervoy
# Processing Record 48 of Set 9 | bartica
# Processing Record 49 of Set 9 | hashtrud
# Processing Record 50 of Set 9 | tabou
# Processing Record 1 of Set 10 | villa carlos paz
# Processing Record 2 of Set 10 | kashi
# Processing Record 3 of Set 10 | gangapur
# Processing Record 4 of Set 10 | muravlenko
# Processing Record 5 of Set 10 | robore
# Processing Record 6 of Set 10 | martinsicuro
# Processing Record 7 of Set 10 | kautokeino
# Processing Record 8 of Set 10 | gravdal
# Processing Record 9 of Set 10 | wattegama
# Processing Record 10 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 11 of Set 10 | mehamn
# Processing Record 12 of Set 10 | maarianhamina
# Processing Record 13 of Set 10 | urengoy
# Processing Record 14 of Set 10 | quatre cocos
# Processing Record 15 of Set 10 | machico
# Processing Record 16 of Set 10 | shahrud
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | elizabeth city
# Processing Record 19 of Set 10 | varkaus
# Processing Record 20 of Set 10 | savannah bight
# Processing Record 21 of Set 10 | ilebo
# Processing Record 22 of Set 10 | danville
# Processing Record 23 of Set 10 | la plata
# Processing Record 24 of Set 10 | aksarayskiy
# Processing Record 25 of Set 10 | shediac
# Processing Record 26 of Set 10 | zhanaozen
# Processing Record 27 of Set 10 | methoni
# Processing Record 28 of Set 10 | pimentel
# Processing Record 29 of Set 10 | tigre
# Processing Record 30 of Set 10 | pital
# Processing Record 31 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 10 | mahajanga
# Processing Record 33 of Set 10 | rorvik
# Processing Record 34 of Set 10 | mercedes
# Processing Record 35 of Set 10 | bilkha
# Processing Record 36 of Set 10 | cherusti
# Processing Record 37 of Set 10 | rundu
# Processing Record 38 of Set 10 | burica
# City not found. Skipping...
# Processing Record 39 of Set 10 | macesu de sus
# Processing Record 40 of Set 10 | borba
# Processing Record 41 of Set 10 | shu
# Processing Record 42 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 10 | olafsvik
# Processing Record 44 of Set 10 | cotonou
# Processing Record 45 of Set 10 | wah
# Processing Record 46 of Set 10 | sao desiderio
# Processing Record 47 of Set 10 | pine castle
# Processing Record 48 of Set 10 | vardo
# Processing Record 49 of Set 10 | kajaani
# Processing Record 50 of Set 10 | itarema
# Processing Record 1 of Set 11 | mwanza
# Processing Record 2 of Set 11 | chornukhy
# Processing Record 3 of Set 11 | palaiokhora
# City not found. Skipping...
# Processing Record 4 of Set 11 | capanema
# Processing Record 5 of Set 11 | hemsedal
# Processing Record 6 of Set 11 | sorland
# Processing Record 7 of Set 11 | umarkot
# Processing Record 8 of Set 11 | maceio
# Processing Record 9 of Set 11 | sept-iles
# Processing Record 10 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 11 | starkville
# Processing Record 12 of Set 11 | kholmy
# Processing Record 13 of Set 11 | tricase
# Processing Record 14 of Set 11 | kedrovka
# Processing Record 15 of Set 11 | shepetivka
# Processing Record 16 of Set 11 | barabinsk
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | north myrtle beach
# Processing Record 19 of Set 11 | kalmunai
# Processing Record 20 of Set 11 | ouesso
# Processing Record 21 of Set 11 | jacareacanga
# Processing Record 22 of Set 11 | ashtabula
# Processing Record 23 of Set 11 | guamal
# Processing Record 24 of Set 11 | abu zabad
# Processing Record 25 of Set 11 | quelimane
# Processing Record 26 of Set 11 | podyuga
# Processing Record 27 of Set 11 | chiredzi
# Processing Record 28 of Set 11 | santa maria
# Processing Record 29 of Set 11 | benjamin aceval
# Processing Record 30 of Set 11 | kulhudhuffushi
# Processing Record 31 of Set 11 | kinsale
# Processing Record 32 of Set 11 | itacare
# Processing Record 33 of Set 11 | llanes
# Processing Record 34 of Set 11 | sayyan
# Processing Record 35 of Set 11 | mananara
# Processing Record 36 of Set 11 | panjab
# Processing Record 37 of Set 11 | tarut
# Processing Record 38 of Set 11 | boa vista
# Processing Record 39 of Set 11 | namwala
# Processing Record 40 of Set 11 | colquechaca
# Processing Record 41 of Set 11 | matagami
# Processing Record 42 of Set 11 | chulym
# Processing Record 43 of Set 11 | pakruojis
# Processing Record 44 of Set 11 | havoysund
# Processing Record 45 of Set 11 | san francisco
# Processing Record 46 of Set 11 | tahoua
# Processing Record 47 of Set 11 | fianarantsoa
# Processing Record 48 of Set 11 | mahibadhoo
# Processing Record 49 of Set 11 | easton
# Processing Record 50 of Set 11 | xuddur
# Processing Record 1 of Set 12 | jaguaribe
# Processing Record 2 of Set 12 | luanda
# Processing Record 3 of Set 12 | camana
# Processing Record 4 of Set 12 | tarbes
# Processing Record 5 of Set 12 | tiruppuvanam
# Processing Record 6 of Set 12 | nizhnyaya tavda
# Processing Record 7 of Set 12 | luau
# Processing Record 8 of Set 12 | amfissa
# Processing Record 9 of Set 12 | rozzano
# Processing Record 10 of Set 12 | morondava
# Processing Record 11 of Set 12 | minudasht
# Processing Record 12 of Set 12 | melilla
# Processing Record 13 of Set 12 | moyale
# Processing Record 14 of Set 12 | klyuchi
# Processing Record 15 of Set 12 | dolores
# Processing Record 16 of Set 12 | camacha
# Processing Record 17 of Set 12 | lieksa
# Processing Record 18 of Set 12 | ekibastuz
# Processing Record 19 of Set 12 | puerto asis
# Processing Record 20 of Set 12 | tsabong
# Processing Record 21 of Set 12 | manicore
# Processing Record 22 of Set 12 | concepcion
# Processing Record 23 of Set 12 | pachino
# Processing Record 24 of Set 12 | nogent-le-rotrou
# Processing Record 25 of Set 12 | new deer
# Processing Record 26 of Set 12 | economy
# Processing Record 27 of Set 12 | kobylka
# Processing Record 28 of Set 12 | alekseyevka
# Processing Record 29 of Set 12 | solaro
# Processing Record 30 of Set 12 | guacimo
# Processing Record 31 of Set 12 | salalah
# Processing Record 32 of Set 12 | vila franca do campo
# Processing Record 33 of Set 12 | mahon
# Processing Record 34 of Set 12 | oksfjord
# Processing Record 35 of Set 12 | mount darwin
# Processing Record 36 of Set 12 | baillif
# Processing Record 37 of Set 12 | kudahuvadhoo
# Processing Record 38 of Set 12 | derbent
# Processing Record 39 of Set 12 | road town
# Processing Record 40 of Set 12 | sakakah
# Processing Record 41 of Set 12 | shambu
# Processing Record 42 of Set 12 | willowmore
# Processing Record 43 of Set 12 | akhtanizovskaya
# Processing Record 44 of Set 12 | tevriz
# Processing Record 45 of Set 12 | ouango
# Processing Record 46 of Set 12 | coihueco
# Processing Record 47 of Set 12 | morant bay
# Processing Record 48 of Set 12 | nalut
# Processing Record 49 of Set 12 | santo antonio do leverger
# Processing Record 50 of Set 12 | sinnamary
# Processing Record 1 of Set 13 | limanowa
# Processing Record 2 of Set 13 | toamasina
# Processing Record 3 of Set 13 | joacaba
# Processing Record 4 of Set 13 | bathurst
# Processing Record 5 of Set 13 | uyo
# Processing Record 6 of Set 13 | san ramon
# Processing Record 7 of Set 13 | male
# Processing Record 8 of Set 13 | persianovskiy
# Processing Record 9 of Set 13 | altay
# Processing Record 10 of Set 13 | sinop
# Processing Record 11 of Set 13 | ramhormoz
# Processing Record 12 of Set 13 | odienne
# Processing Record 13 of Set 13 | sao jose da tapera
# Processing Record 14 of Set 13 | lubao
# Processing Record 15 of Set 13 | trelew
# Processing Record 16 of Set 13 | iskateley
# Processing Record 17 of Set 13 | punta alta
# Processing Record 18 of Set 13 | borne
# Processing Record 19 of Set 13 | ust-kalmanka
# Processing Record 20 of Set 13 | nokaneng
# Processing Record 21 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 22 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 13 | ahar
# Processing Record 24 of Set 13 | cervo
# Processing Record 25 of Set 13 | maragogi
# Processing Record 26 of Set 13 | meulaboh
# Processing Record 27 of Set 13 | villa maria
# Processing Record 28 of Set 13 | hvide sande
# Processing Record 29 of Set 13 | varhaug
# Processing Record 30 of Set 13 | dourbali
# Processing Record 31 of Set 13 | soledade
# Processing Record 32 of Set 13 | sucua
# Processing Record 33 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 34 of Set 13 | formosa
# Processing Record 35 of Set 13 | awbari
# Processing Record 36 of Set 13 | sao miguel do araguaia
# Processing Record 37 of Set 13 | mtwara
# Processing Record 38 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 13 | waterloo
# Processing Record 40 of Set 13 | sur
# Processing Record 41 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 13 | dalmatovo
# Processing Record 43 of Set 13 | maralal
# Processing Record 44 of Set 13 | san andres
# Processing Record 45 of Set 13 | nara
# Processing Record 46 of Set 13 | sechura
# Processing Record 47 of Set 13 | gao
# Processing Record 48 of Set 13 | jalu
# Processing Record 49 of Set 13 | shostka
# Processing Record 50 of Set 13 | sehithwa
# Processing Record 1 of Set 14 | urumqi
# Processing Record 2 of Set 14 | pulaski
# Processing Record 3 of Set 14 | cururupu
# Processing Record 4 of Set 14 | segezha
# Processing Record 5 of Set 14 | belem de sao francisco
# Processing Record 6 of Set 14 | castletown
# Processing Record 7 of Set 14 | gobabis
# Processing Record 8 of Set 14 | njeru
# Processing Record 9 of Set 14 | kasongo-lunda
# Processing Record 10 of Set 14 | kalabo
# Processing Record 11 of Set 14 | edenderry
# Processing Record 12 of Set 14 | ugoofaaru
# Processing Record 13 of Set 14 | gzhatsk
# City not found. Skipping...
# Processing Record 14 of Set 14 | geraldton
# Processing Record 15 of Set 14 | las palmas
# Processing Record 16 of Set 14 | kyrylivka
# Processing Record 17 of Set 14 | cherdyn
# Processing Record 18 of Set 14 | tashtyp
# Processing Record 19 of Set 14 | gunib
# Processing Record 20 of Set 14 | atasu
# Processing Record 21 of Set 14 | mumford
# Processing Record 22 of Set 14 | outjo
# Processing Record 23 of Set 14 | tulum
# Processing Record 24 of Set 14 | gamba
# Processing Record 25 of Set 14 | quballat
# Processing Record 26 of Set 14 | pangody
# Processing Record 27 of Set 14 | abeche
# Processing Record 28 of Set 14 | horta
# Processing Record 29 of Set 14 | cabedelo
# Processing Record 30 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 14 | salinas
# Processing Record 32 of Set 14 | chortomlyk
# Processing Record 33 of Set 14 | vagay
# Processing Record 34 of Set 14 | mecca
# Processing Record 35 of Set 14 | mayor pablo lagerenza
# Processing Record 36 of Set 14 | beruwala
# Processing Record 37 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 14 | kembe
# Processing Record 39 of Set 14 | arrifes
# Processing Record 40 of Set 14 | mbanza-ngungu
# Processing Record 41 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 42 of Set 14 | tarashcha
# Processing Record 43 of Set 14 | diapaga
# Processing Record 44 of Set 14 | oistins
# Processing Record 45 of Set 14 | bizhbulyak
# Processing Record 46 of Set 14 | strzelce opolskie
# Processing Record 47 of Set 14 | ankazoabo
# Processing Record 48 of Set 14 | machiques
# Processing Record 49 of Set 14 | farah
# Processing Record 50 of Set 14 | sobradinho
# Processing Record 1 of Set 15 | rio pardo de minas
# Processing Record 2 of Set 15 | marinhas
# Processing Record 3 of Set 15 | lucea
# Processing Record 4 of Set 15 | bayonet point
# Processing Record 5 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 15 | ciudad bolivar
# Processing Record 7 of Set 15 | taoudenni
# Processing Record 8 of Set 15 | bingerville
# Processing Record 9 of Set 15 | laguna
# Processing Record 10 of Set 15 | padang
# Processing Record 11 of Set 15 | addis zemen
# City not found. Skipping...
# Processing Record 12 of Set 15 | ardakan
# Processing Record 13 of Set 15 | el alto
# Processing Record 14 of Set 15 | kankon
# Processing Record 15 of Set 15 | montepuez
# Processing Record 16 of Set 15 | sao sebastiao
# Processing Record 17 of Set 15 | le port
# Processing Record 18 of Set 15 | rasra
# Processing Record 19 of Set 15 | elliot
# Processing Record 20 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 21 of Set 15 | oussouye
# Processing Record 22 of Set 15 | conde
# Processing Record 23 of Set 15 | boende
# Processing Record 24 of Set 15 | lugovoy
# Processing Record 25 of Set 15 | lofos
# Processing Record 26 of Set 15 | iquique
# Processing Record 27 of Set 15 | kurchum
# Processing Record 28 of Set 15 | filingue
# Processing Record 29 of Set 15 | shevchenkove
# Processing Record 30 of Set 15 | kalangala
# Processing Record 31 of Set 15 | mbalmayo
# Processing Record 32 of Set 15 | vredendal
# Processing Record 33 of Set 15 | buta
# Processing Record 34 of Set 15 | kathmandu
# Processing Record 35 of Set 15 | derzhavinsk
# Processing Record 36 of Set 15 | elat
# Processing Record 37 of Set 15 | raudeberg
# Processing Record 38 of Set 15 | lisakovsk
# Processing Record 39 of Set 15 | sumkino
# Processing Record 40 of Set 15 | paamiut
# Processing Record 41 of Set 15 | kinshasa
# Processing Record 42 of Set 15 | aljezur
# Processing Record 43 of Set 15 | entre rios
# Processing Record 44 of Set 15 | huanuco
# Processing Record 45 of Set 15 | constitucion
# Processing Record 46 of Set 15 | svobodnyy
# Processing Record 47 of Set 15 | guiratinga
# Processing Record 48 of Set 15 | sogne
# Processing Record 49 of Set 15 | eten
# Processing Record 50 of Set 15 | ampanihy
# Processing Record 1 of Set 16 | gudari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kontagora  10.3999    5.4695     72.77        57          11
# 1          Qaanaaq  77.4840  -69.3632     -0.83        68           0
# 2        Salamiyah  35.0113   37.0532     64.63        74          58
# 3          Biltine  14.5333   20.9167     82.72        22           2
# 4          Butembo   0.1500   29.2833     57.18        97          99
# 5          Zuwarah  32.9312   12.0820     72.54        63           3
# 6        Jamestown  42.0970  -79.2353     38.71        98         100
# 7       Georgetown   5.4112  100.3354     78.24        88          20
# 8  Arraial Do Cabo -22.9661  -42.0278     72.30        88         100
# 9             Lebu -37.6167  -73.6500     52.32        87          50
#
#    Wind Speed Country       Description
# 0        1.61      NG        few clouds
# 1       10.87      GL         clear sky
# 2        4.83      SY     broken clouds
# 3        8.61      TD         clear sky
# 4        3.29      CD   overcast clouds
# 5        4.59      LY         clear sky
# 6       16.11      US     moderate rain
# 7        3.44      MY        light rain
# 8       22.30      BR   overcast clouds
# 9        8.77      CL  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kontagora      NG  10.3999    5.4695     72.77        57          11
# 1          Qaanaaq      GL  77.4840  -69.3632     -0.83        68           0
# 2        Salamiyah      SY  35.0113   37.0532     64.63        74          58
# 3          Biltine      TD  14.5333   20.9167     82.72        22           2
# 4          Butembo      CD   0.1500   29.2833     57.18        97          99
# 5          Zuwarah      LY  32.9312   12.0820     72.54        63           3
# 6        Jamestown      US  42.0970  -79.2353     38.71        98         100
# 7       Georgetown      MY   5.4112  100.3354     78.24        88          20
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     72.30        88         100
# 9             Lebu      CL -37.6167  -73.6500     52.32        87          50
#
#    Wind Speed       Description
# 0        1.61        few clouds
# 1       10.87         clear sky
# 2        4.83     broken clouds
# 3        8.61         clear sky
# 4        3.29   overcast clouds
# 5        4.59         clear sky
# 6       16.11     moderate rain
# 7        3.44        light rain
# 8       22.30   overcast clouds
# 9        8.77  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
